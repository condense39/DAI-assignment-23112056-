# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/economic-indicators-and-inflation/Economic Indicators And Inflation.csv
# /kaggle/input/economic-indicators-and-inflation/Economic Indicators And Inflation (1) (1).csv
# /kaggle/input/dai-assignment/Economic Indicators And Inflation (1) (1).csv

# %%
import kagglehub

# %%
economic_indicators_and_inflation_path = kagglehub.dataset_download('adilshamim8/economic-indicators-and-inflation')

# %%
economic_indicators_and_inflation_path
# Out:
# '/kaggle/input/economic-indicators-and-inflation'

# %%
import pandas as pd
df=pd.read_csv("/kaggle/input/dai-assignment/Economic Indicators And Inflation (1) (1).csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
# df = pd.read_csv('/mnt/data/Economic Indicators And Inflation (1) (1).csv')

# Display basic info
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 304 non-null    object
#  1    Year                   304 non-null    int64
#  2    GDP (in billion USD)   304 non-null    float64
#  3    Inflation Rate (%)     304 non-null    float64
#  4    Unemployment Rate (%)  304 non-null    float64
#  5    Economic Growth (%)    304 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 14.4+ KB
# None
#               Year  GDP (in billion USD)  Inflation Rate (%)  \
# count   304.000000            304.000000          304.000000
# mean   2017.500000           3383.430921            4.807105
# std       4.617373           4283.442479            7.261215
# min    2010.000000            105.000000           -1.200000
# 25%    2013.750000           1114.250000            1.700000
# ...

# %%
# Univariate Analysis
numeric_cols = df.select_dtypes(include=['number']).columns

# %%
# Histograms
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Box Plots
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col])
    plt.title(f'Box Plot of {col}')
    plt.show()

# %%
# Multivariate Analysis
# Correlation Matrix
plt.figure(figsize=(10, 6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
# Pairplot (Scatterplot for numeric columns)
sns.pairplot(df[numeric_cols])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
# Line Plots
for col in numeric_cols:
    plt.figure(figsize=(10, 5))
    plt.plot(df[col])
    plt.title(f'Line Plot of {col}')
    plt.xlabel('Index')
    plt.ylabel(col)
    plt.show()

# %%
# Violin Plots
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.violinplot(y=df[col])
    plt.title(f'Violin Plot of {col}')
    plt.show()

# %%
# Count Plots for Categorical Columns
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=df[col])
    plt.xticks(rotation=90)
    plt.title(f'Count Plot of {col}')
    plt.show()
